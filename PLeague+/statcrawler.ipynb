# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from datetime import datetime

# %%
def header():
    return {
        "accept": "application/json, text/javascript, */*; q=0.01",
        "accept-encoding": "gzip, deflate, br",
        "accept-language": "zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6",
        "cookie": "PHPSESSID=6qbctjqkjpcq6akosbsnosc7f9; _ga=GA1.1.2039077758.1649901582; _ga_E4T1HDWQ3D=GS1.1.1650807763.5.1.1650808386.58",
        # "referer": "https://pleagueofficial.com/game/151",
        "sec-ch-ua": '''" Not A;Brand";v="99", "Chromium";v="100", "Google Chrome";v="100"''',
        "sec-ch-ua-mobile": "?1",
        "sec-ch-ua-platform": "'Android'",
        "sec-fetch-dest": "empty",
        "sec-fetch-mode": "cors",
        "sec-fetch-site": "same-origin",
        "user-agent": "Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.88 Mobile Safari/537.36",
        "x-requested-with": "XMLHttpRequest",
        
    }

# %%
header()
# Out:
# {'accept': 'application/json, text/javascript, */*; q=0.01',
#  'accept-encoding': 'gzip, deflate, br',
#  'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7,zh-CN;q=0.6',
#  'cookie': 'PHPSESSID=6qbctjqkjpcq6akosbsnosc7f9; _ga=GA1.1.2039077758.1649901582; _ga_E4T1HDWQ3D=GS1.1.1650807763.5.1.1650808386.58',
#  'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="100", "Google Chrome";v="100"',
#  'sec-ch-ua-mobile': '?1',
#  'sec-ch-ua-platform': "'Android'",
#  'sec-fetch-dest': 'empty',
#  'sec-fetch-mode': 'cors',
#  'sec-fetch-site': 'same-origin',
#  'user-agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.88 Mobile Safari/537.36',
#  'x-requested-with': 'XMLHttpRequest'}

# %%
url = "https://pleagueofficial.com/api/boxscore.php?id=110&away_tab=total&home_tab=total"


res = requests.get(
    url, headers=header()
)

# %%
res.json()['data']['home']
# Out:
# [{'points': 16,
#   'positive': -8,
#   'seconds': 1284,
#   'starter': '〇',
#   'turnover': 0,
#   'ast': 4,
#   'blk': 0,
#   'reb_d': 8,
#   'eff': 25,
#   'efgp': '57.1%',
#   'ft_m': 8,
#   'ft_a': 0,
#   'reb_o': 0,
#   'pfoul': 1,
#   'profile_picture': None,
#   'name_alt': '羅賓森',
#   'player_id': 114,
#   'name': None,
#   'jersey': '0',
#   'position': None,
#   'stl': 0,
#   'trey_m': 0,
#   'trey_a': 0,
#   'reb': 8,
#   'tsp': '76%',
#   'two_m': 4,
#   'two_a': 3,
#   'ugp': '21.3%',
#   'mins': '21:24',
#   'two': 7,
#   'two_m_two': '4-7',
#   'twop': '57.1%',
#   'trey': 0,
#   'trey_m_trey': '0-0',
#   'treyp': '0%',
#   'ft': 8,
#   'ft_m_ft': '8-8',
#   'ftp': '100%'},
#  {'points': 12,
#   'positive': -20,
#   'seconds': 1915,
#   'starter': '〇',
#   'turnover': 2,
#   'ast': 4,
#   'blk': 0,
#   'reb_d': 1,
#   'eff': 11,
#   'efgp': '71.4%',
#   'ft_m': 2,
#   'ft_a': 2,
#   'reb_o': 1,
#   'pfoul': 4,
#   'profile_picture': '',
#   'name_alt': '吳家駿',
#   'player_id': 16,
#   'name': None,
#   'jersey': '3',
#   'position': 'G',
#   'stl': 0,
#   'trey_m': 2,
#   'trey_a': 1,
#   'reb': 2,
#   'tsp': '68.5%',
#   'two_m': 2,
#   'two_a': 2,
#   'ugp': '14.8%',
#   'mins': '31:55',
#   'two': 4,
#   'two_m_two': '2-4',
#   'twop': '50%',
#   'trey': 3,
#   'trey_m_trey': '2-3',
#   'treyp': '66.7%',
#   'ft': 4,
#   'ft_m_ft': '2-4',
#   'ftp': '50%'},
#  {'points': 3,
#   'positive': -17,
#   'seconds': 897,
#   'starter': '',
#   'turnover': 1,
#   'ast': 2,
#   'blk': 0,
#   'reb_d': 1,
#   'eff': 6,
#   'efgp': '0%',
#   'ft_m': 3,
#   'ft_a': 1,
#   'reb_o': 3,
#   'pfoul': 3,
#   'profile_picture': '',
#   'name_alt': '施顏宗',
#   'player_id': 15,
#   'name': None,
#   'jersey': '5',
#   'position': 'G',
#   'stl': 1,
#   'trey_m': 0,
#   'trey_a': 2,
#   'reb': 4,
#   'tsp': '39.9%',
#   'two_m': 0,
#   'two_a': 0,
#   'ugp': '14.5%',
#   'mins': '14:57',
#   'two': 0,
#   'two_m_two': '0-0',
#   'twop': '0%',
#   'trey': 2,
#   'trey_m_trey': '0-2',
#   'treyp': '0%',
#   'ft': 4,
#   'ft_m_ft': '3-4',
#   'ftp': '75%'},
#  {'points': 3,
#   'positive': 2,
#   'seconds': 759,
#   'starter': '',
#   'turnover': 1,
#   'ast': 1,
#   'blk': 0,
#   'reb_d': 1,
#   'eff': -2,
#   'efgp': '0%',
#   'ft_m': 3,
#   'ft_a': 1,
#   'reb_o': 0,
#   'pfoul': 1,
#   'profile_picture': '',
#   'name_alt': '關達祐',
#   'player_id': 17,
#   'name': None,
#   'jersey': '6',
#   'position': 'G',
#   'stl': 0,
#   'trey_m': 0,
#   'trey_a': 3,
#   'reb': 1,
#   'tsp': '22.2%',
#   'two_m': 0,
#   'two_a': 2,
#   'ugp': '27.6%',
#   'mins': '12:39',
#   'two': 2,
#   'two_m_two': '0-2',
#   'twop': '0%',
#   'trey': 3,
#   'trey_m_trey': '0-3',
#   'treyp': '0%',
#   'ft': 4,
#   'ft_m_ft': '3-4',
#   'ftp': '75%'},
#  {'points': 0,
#   'positive': 7,
#   'seconds': 1109,
#   'starter': '〇',
#   'turnover': 0,
#   'ast': 1,
#   'blk': 1,
#   'reb_d': 1,
#   'eff': 3,
#   'efgp': '0%',
#   'ft_m': 0,
#   'ft_a': 0,
#   'reb_o': 2,
#   'pfoul': 2,
#   'profile_picture': '',
#   'name_alt': '林耀宗',
#   'player_id': 18,
#   'name': None,
#   'jersey': '7',
#   'position': 'G',
#   'stl': 0,
#   'trey_m': 0,
#   'trey_a': 0,
#   'reb': 3,
#   'tsp': '0%',
#   'two_m': 0,
#   'two_a': 2,
#   'ugp': '4.7%',
#   'mins': '18:29',
#   'two': 2,
#   'two_m_two': '0-2',
#   'twop': '0%',
#   'trey': 0,
#   'trey_m_trey': '0-0',
#   'treyp': '0%',
#   'ft': 0,
#   'ft_m_ft': '0-0',
#   'ftp': '0%'},
#  {'points': 5,
#   'positive': 6,
#   'seconds': 861,
#   'starter': '',
#   'turnover': 0,
#   'ast': 0,
#   'blk': 0,
#   'reb_d': 1,
#   'eff': 7,
#   'efgp': '83.3%',
#   'ft_m': 0,
#   'ft_a': 0,
#   'reb_o': 0,
#   'pfoul': 1,
#   'profile_picture': '',
#   'name_alt': '李家慷',
#   'player_id': 23,
#   'name': None,
#   'jersey': '12',
#   'position': 'G',
#   'stl': 2,
#   'trey_m': 1,
#   'trey_a': 1,
#   'reb': 1,
#   'tsp': '83.3%',
#   'two_m': 1,
#   'two_a': 0,
#   'ugp': '9.1%',
#   'mins': '14:21',
#   'two': 1,
#   'two_m_two': '1-1',
#   'twop': '100%',
#   'trey': 2,
#   'trey_m_trey': '1-2',
#   'treyp': '50%',
#   'ft': 0,
#   'ft_m_ft': '0-0',
#   'ftp': '0%'},
#  {'points': 2,
#   'positive': -20,
#   'seconds': 925,
#   'starter': '',
#   'turnover': 1,
#   'ast': 0,
#   'blk': 0,
#   'reb_d': 2,
#   'eff': 0,
#   'efgp': '25%',
#   'ft_m': 0,
#   'ft_a': 2,
#   'reb_o': 1,
#   'pfoul': 2,
#   'profile_picture': None,
#   'name_alt': '陳昱瑞',
#   'player_id': 77,
#   'name': None,
#   'jersey': '13',
#   'position': None,
#   'stl': 1,
#   'trey_m': 0,
#   'trey_a': 1,
#   'reb': 3,
#   'tsp': '20.5%',
#   'two_m': 1,
#   'two_a': 2,
#   'ugp': '16.7%',
#   'mins': '15:25',
#   'two': 3,
#   'two_m_two': '1-3',
#   'twop': '33.3%',
#   'trey': 1,
#   'trey_m_trey': '0-1',
#   'treyp': '0%',
#   'ft': 2,
#   'ft_m_ft': '0-2',
#   'ftp': '0%'},
#  {'points': 27,
#   'positive': -9,
#   'seconds': 1724,
#   'starter': '〇',
#   'turnover': 1,
#   'ast': 0,
#   'blk': 1,
#   'reb_d': 1,
#   'eff': 27,
#   'efgp': '62.5%',
#   'ft_m': 2,
#   'ft_a': 0,
#   'reb_o': 4,
#   'pfoul': 3,
#   'profile_picture': None,
#   'name_alt': '貝索維奇',
#   'player_id': 120,
#   'name': None,
#   'jersey': '18',
#   'position': None,
#   'stl': 3,
#   'trey_m': 1,
#   'trey_a': 3,
#   'reb': 5,
#   'tsp': '64.7%',
#   'two_m': 11,
#   'two_a': 5,
#   'ugp': '33.3%',
#   'mins': '28:44',
#   'two': 16,
#   'two_m_two': '11-16',
#   'twop': '68.8%',
#   'trey': 4,
#   'trey_m_trey': '1-4',
#   'treyp': '25%',
#   'ft': 2,
#   'ft_m_ft': '2-2',
#   'ftp': '100%'},
#  {'points': '',
#   'positive': '',
#   'seconds': '',
#   'starter': '',
#   'turnover': '',
#   'ast': '',
#   'blk': '',
#   'reb_d': '',
#   'eff': '',
#   'efgp': '',
#   'ft_m': '',
#   'ft_a': '',
#   'reb_o': '',
#   'pfoul': '',
#   'profile_picture': '',
#   'name_alt': '黃泓瀚',
#   'player_id': 75,
#   'name': '',
#   'jersey': '22',
#   'position': '',
#   'stl': '',
#   'trey_m': '',
#   'trey_a': '',
#   'reb': '',
#   'tsp': '',
#   'two_m': '',
#   'two_a': '',
#   'ugp': '',
#   'mins': 'DNP',
#   'two': '',
#   'two_m_two': '',
#   'twop': '',
#   'trey': '',
#   'trey_m_trey': '',
#   'treyp': '',
#   'ft': '',
#   'ft_m_ft': '',
#   'ftp': ''},
#  {'points': 18,
#   'positive': -8,
#   'seconds': 1884,
#   'starter': '〇',
#   'turnover': 2,
#   'ast': 2,
#   'blk': 0,
#   'reb_d': 4,
#   'eff': 12,
#   'efgp': '47.1%',
#   'ft_m': 2,
#   'ft_a': 1,
#   'reb_o': 1,
#   'pfoul': 2,
#   'profile_picture': '',
#   'name_alt': '施晉堯',
#   'player_id': 24,
#   'name': None,
#   'jersey': '28',
#   'position': 'G',
#   'stl': 1,
#   'trey_m': 4,
#   'trey_a': 8,
#   'reb': 5,
#   'tsp': '49.1%',
#   'two_m': 2,
#   'two_a': 3,
#   'ugp': '27.9%',
#   'mins': '31:24',
#   'two': 5,
#   'two_m_two': '2-5',
#   'twop': '40%',
#   'trey': 12,
#   'trey_m_trey': '4-12',
#   'treyp': '33.3%',
#   'ft': 3,
#   'ft_m_ft': '2-3',
#   'ftp': '66.7%'},
#  {'points': 7,
#   'positive': -12,
#   'seconds': 1296,
#   'starter': '',
#   'turnover': 3,
#   'ast': 1,
#   'blk': 0,
#   'reb_d': 3,
#   'eff': 3,
#   'efgp': '31.3%',
#   'ft_m': 2,
#   'ft_a': 0,
#   'reb_o': 1,
#   'pfoul': 2,
#   'profile_picture': '',
#   'name_alt': '陳冠全',
#   'player_id': 20,
#   'name': None,
#   'jersey': '30',
#   'position': 'G',
#   'stl': 0,
#   'trey_m': 1,
#   'trey_a': 3,
#   'reb': 4,
#   'tsp': '39.4%',
#   'two_m': 1,
#   'two_a': 3,
#   'ugp': '24.1%',
#   'mins': '21:36',
#   'two': 4,
#   'two_m_two': '1-4',
#   'twop': '25%',
#   'trey': 4,
#   'trey_m_trey': '1-4',
#   'treyp': '25%',
#   'ft': 2,
#   'ft_m_ft': '2-2',
#   'ftp': '100%'},
#  {'points': 0,
#   'positive': 0,
#   'seconds': 257,
#   'starter': '',
#   'turnover': 0,
#   'ast': 0,
#   'blk': 0,
#   'reb_d': 0,
#   'eff': -1,
#   'efgp': '0%',
#   'ft_m': 0,
#   'ft_a': 0,
#   'reb_o': 0,
#   'pfoul': 0,
#   'profile_picture': None,
#   'name_alt': '溫立煌',
#   'player_id': 78,
#   'name': None,
#   'jersey': '45',
#   'position': None,
#   'stl': 0,
#   'trey_m': 0,
#   'trey_a': 0,
#   'reb': 0,
#   'tsp': '0%',
#   'two_m': 0,
#   'two_a': 1,
#   'ugp': '10.7%',
#   'mins': '04:17',
#   'two': 1,
#   'two_m_two': '0-1',
#   'twop': '0%',
#   'trey': 0,
#   'trey_m_trey': '0-0',
#   'treyp': '0%',
#   'ft': 0,
#   'ft_m_ft': '0-0',
#   'ftp': '0%'},
#  {'points': 4,
#   'positive': -16,
#   'seconds': 1489,
#   'starter': '',
#   'turnover': 1,
#   'ast': 2,
#   'blk': 0,
#   'reb_d': 4,
#   'eff': 0,
#   'efgp': '9.1%',
#   'ft_m': 2,
#   'ft_a': 0,
#   'reb_o': 0,
#   'pfoul': 1,
#   'profile_picture': None,
#   'name_alt': '盧峻翔',
#   'player_id': 76,
#   'name': None,
#   'jersey': '69',
#   'position': None,
#   'stl': 1,
#   'trey_m': 0,
#   'trey_a': 4,
#   'reb': 4,
#   'tsp': '16.8%',
#   'two_m': 1,
#   'two_a': 6,
#   'ugp': '22.9%',
#   'mins': '24:49',
#   'two': 7,
#   'two_m_two': '1-7',
#   'twop': '14.3%',
#   'trey': 4,
#   'trey_m_trey': '0-4',
#   'treyp': '0%',
#   'ft': 2,
#   'ft_m_ft': '2-2',
#   'ftp': '100%'}]

# %%
res.json()
# Out:
# {'error': '',
#  'data': {'q1_home': 24,
#   'q1_away': 40,
#   'q2_home': 22,
#   'q2_away': 26,
#   'q3_home': 31,
#   'q3_away': 17,
#   'q4_home': 27,
#   'q4_away': 14,
#   'ot1_home': '-',
#   'ot1_away': '-',
#   'ot2_home': '-',
#   'ot2_away': '-',
#   'score_home': '104',
#   'score_away': '97',
#   'home': [{'points': 8,
#     'positive': -6,
#     'seconds': 1134,
#     'starter': '',
#     'turnover': 1,
#     'ast': 2,
#     'blk': 0,
#     'reb_d': 1,
#     'eff': 9,
#     'efgp': '70%',
#     'ft_m': 1,
#     'ft_a': 0,
#     'reb_o': 0,
#     'pfoul': 1,
#     'profile_picture': None,
#     'name_alt': '陳振傑',
#     'player_id': 41,
#     'name': None,
#     'jersey': '0',
#     'position': None,
#     'stl': 1,
#     'trey_m': 1,
#     'trey_a': 2,
#     'reb': 1,
#     'tsp': '73.5%',
#     'two_m': 2,
#     'two_a': 0,
#     'ugp': '16.2%',
#     'mins': '18:54',
#     'two': 2,
#     'two_m_two': '2-2',
#     'twop': '100%',
#     'trey': 3,
#     'trey_m_trey': '1-3',
#     'treyp': '33.3%',
#     'ft': 1,
#     'ft_m_ft': '1-1',
#     'ftp': '100%'},
#    {'points': 8,
#     'positive': 5,
#     'seconds': 1301,
#     'starter': '〇',
#     'turnover': 1,
#     'ast': 0,
#     'blk': 0,
#     'reb_d': 0,
#     'eff': 5,
#     'efgp': '87.5%',
#     'ft_m': 1,
#     'ft_a': 2,
#     'reb_o': 1,
#     'pfoul': 4,
#     'profile_picture': None,
#     'name_alt': '成力煥',
#     'player_id': 27,
#     'name': None,
#     'jersey': '7',
#     'position': None,
#     'stl': 0,
#     'trey_m': 1,
#     'trey_a': 1,
#     'reb': 1,
#     'tsp': '75.2%',
#     'two_m': 2,
#     'two_a': 0,
#     'ugp': '13.6%',
#     'mins': '21:41',
#     'two': 2,
#     'two_m_two': '2-2',
#     'twop': '100%',
#     'trey': 2,
#     'trey_m_trey': '1-2',
#     'treyp': '50%',
#     'ft': 3,
#     'ft_m_ft': '1-3',
#     'ftp': '33.3%'},
#    {'points': '',
#     'positive': '',
#     'seconds': '',
#     'starter': '',
#     'turnover': '',
#     'ast': '',
#     'blk': '',
#     'reb_d': '',
#     'eff': '',
#     'efgp': '',
#     'ft_m': '',
#     'ft_a': '',
#     'reb_o': '',
#     'pfoul': '',
#     'profile_picture': '',
#     'name_alt': '王振原',
#     'player_id': 81,
#     'name': '',
#     'jersey': '8',
#     'position': '',
#     'stl': '',
#     'trey_m': '',
#     'trey_a': '',
#     'reb': '',
#     'tsp': '',
#     'two_m': '',
#     'two_a': '',
#     'ugp': '',
#     'mins': 'DNP',
#     'two': '',
#     'two_m_two': '',
#     'twop': '',
#     'trey': '',
#     'trey_m_trey': '',
#     'treyp': '',
#     'ft': '',
#     'ft_m_ft': '',
#     'ftp': ''},
#    {'points': 6,
#     'positive': -16,
#     'seconds': 1180,
#     'starter': '',
#     'turnover': 1,
#     'ast': 1,
#     'blk': 0,
#     'reb_d': 0,
#     'eff': 4,
#     'efgp': '60%',
#     'ft_m': 0,
#     'ft_a': 0,
#     'reb_o': 1,
#     'pfoul': 1,
#     'profile_picture': None,
#     'name_alt': '林俊吉',
#     'player_id': 48,
#     'name': None,
#     'jersey': '11',
#     'position': None,
#     'stl': 0,
#     'trey_m': 2,
#     'trey_a': 3,
#     'reb': 1,
#     'tsp': '60%',
#     'two_m': 0,
#     'two_a': 0,
#     'ugp': '14.3%',
#     'mins': '19:40',
#     'two': 0,
#     'two_m_two': '0-0',
#     'twop': '0%',
#     'trey': 5,
#     'trey_m_trey': '2-5',
#     'treyp': '40%',
#     'ft': 0,
#     'ft_m_ft': '0-0',
#     'ftp': '0%'},
#    {'points': 12,
#     'positive': 23,
#     'seconds': 1705,
#     'starter': '〇',
#     'turnover': 1,
#     'ast': 6,
#     'blk': 0,
#     'reb_d': 5,
#     'eff': 14,
#     'efgp': '42.9%',
#     'ft_m': 0,
#     'ft_a': 0,
#     'reb_o': 0,
#     'pfoul': 2,
#     'profile_picture': None,
#     'name_alt': '吳永盛',
#     'player_id': 82,
#     'name': None,
#     'jersey': '14',
#     'position': None,
#     'stl': 1,
#     'trey_m': 2,
#     'trey_a': 6,
#     'reb': 5,
#     'tsp': '42.9%',
#     'two_m': 3,
#     'two_a': 3,
#     'ugp': '24.3%',
#     'mins': '28:25',
#     'two': 6,
#     'two_m_two': '3-6',
#     'twop': '50%',
#     'trey': 8,
#     'trey_m_trey': '2-8',
#     'treyp': '25%',
#     'ft': 0,
#     'ft_m_ft': '0-0',
#     'ftp': '0%'},
#    {'points': '',
#     'positive': '',
#     'seconds': '',
#     'starter': '',
#     'turnover': '',
#     'ast': '',
#     'blk': '',
#     'reb_d': '',
#     'eff': '',
#     'efgp': '',
#     'ft_m': '',
#     'ft_a': '',
#     'reb_o': '',
#     'pfoul': '',
#     'profile_picture': '',
#     'name_alt': '楊盛硯',
#     'player_id': 51,
#     'name': '',
#     'jersey': '18',
#     'position': '',
#     'stl': '',
#     'trey_m': '',
#     'trey_a': '',
#     'reb': '',
#     'tsp': '',
#     'two_m': '',
#     'two_a': '',
#     'ugp': '',
#     'mins': 'DNP',
#     'two': '',
#     'two_m_two': '',
#     'twop': '',
#     'trey': '',
#     'trey_m_trey': '',
#     'treyp': '',
#     'ft': '',
#     'ft_m_ft': '',
#     'ftp': ''},
#    {'points': 19,
#     'positive': 3,
#     'seconds': 1393,
#     'starter': '',
#     'turnover': 1,
#     'ast': 1,
#     'blk': 0,
#     'reb_d': 2,
#     'eff': 13,
#     'efgp': '55.9%',
#     'ft_m': 0,
#     'ft_a': 0,
#     'reb_o': 1,
#     'pfoul': 0,
#     'profile_picture': None,
#     'name_alt': '簡浩',
#     'player_id': 80,
#     'name': None,
#     'jersey': '21',
#     'position': None,
#     'stl': 1,
#     'trey_m': 5,
#     'trey_a': 8,
#     'reb': 3,
#     'tsp': '55.9%',
#     'two_m': 2,
#     'two_a': 2,
#     'ugp': '35.5%',
#     'mins': '23:13',
#     'two': 4,
#     'two_m_two': '2-4',
#     'twop': '50%',
#     'trey': 13,
#     'trey_m_trey': '5-13',
#     'treyp': '38.5%',
#     'ft': 0,
#     'ft_m_ft': '0-0',
#     'ftp': '0%'},
#    {'points': 10,
#     'positive': 6,
#     'seconds': 2392,
#     'starter': '〇',
#     'turnover': 4,
#     'ast': 1,
#     'blk': 0,
#     'reb_d': 5,
#     'eff': 9,
#     'efgp': '50%',
#     'ft_m': 0,
#     'ft_a': 1,
#     'reb_o': 0,
#     'pfoul': 4,
#     'profile_picture': None,
#     'name_alt': '錢肯尼',
#     'player_id': 65,
#     'name': None,
#     'jersey': '23',
#     'position': None,
#     'stl': 4,
#     'trey_m': 2,
#     'trey_a': 3,
#     'reb': 5,
#     'tsp': '47.9%',
#     'two_m': 2,
#     'two_a': 3,
#     'ugp': '16.8%',
#     'mins': '39:52',
#     'two': 5,
#     'two_m_two': '2-5',
#     'twop': '40%',
#     'trey': 5,
#     'trey_m_trey': '2-5',
#     'treyp': '40%',
#     'ft': 1,
#     'ft_m_ft': '0-1',
#     'ftp': '0%'},
#    {'points': 3,
#     'positive': 13,
#     'seconds': 1879,
#     'starter': '〇',
#     'turnover': 1,
#     'ast': 4,
#     'blk': 0,
#     'reb_d': 6,
#     'eff': 6,
#     'efgp': '11.1%',
#     'ft_m': 1,
#     'ft_a': 1,
#     'reb_o': 3,
#     'pfoul': 0,
#     'profile_picture': None,
#     'name_alt': '忻沃克',
#     'player_id': 70,
#     'name': 'Randall Walko',
#     'jersey': '24',
#     'position': None,
#     'stl': 0,
#     'trey_m': 0,
#     'trey_a': 3,
#     'reb': 9,
#     'tsp': '15.2%',
#     'two_m': 1,
#     'two_a': 5,
#     'ugp': '15.9%',
#     'mins': '31:19',
#     'two': 6,
#     'two_m_two': '1-6',
#     'twop': '16.7%',
#     'trey': 3,
#     'trey_m_trey': '0-3',
#     'treyp': '0%',
#     'ft': 2,
#     'ft_m_ft': '1-2',
#     'ftp': '50%'},
#    {'points': '',
#     'positive': '',
#     'seconds': '',
#     'starter': '',
#     'turnover': '',
#     'ast': '',
#     'blk': '',
#     'reb_d': '',
#     'eff': '',
#     'efgp': '',
#     'ft_m': '',
#     'ft_a': '',
#     'reb_o': '',
#     'pfoul': '',
#     'profile_picture': '',
#     'name_alt': '吳松蔚',
#     'player_id': 53,
#     'name': '',
#     'jersey': '30',
#     'position': '',
#     'stl': '',
#     'trey_m': '',
#     'trey_a': '',
#     'reb': '',
#     'tsp': '',
#     'two_m': '',
#     'two_a': '',
#     'ugp': '',
#     'mins': 'DNP',
#     'two': '',
#     'two_m_two': '',
#     'twop': '',
#     'trey': '',
#     'trey_m_trey': '',
#     'treyp': '',
#     'ft': '',
#     'ft_m_ft': '',
#     'ftp': ''},
#    {'points': 25,
#     'positive': 13,
#     'seconds': 1769,
#     'starter': '〇',
#     'turnover': 1,
#     'ast': 4,
#     'blk': 0,
#     'reb_d': 4,
#     'eff': 30,
#     'efgp': '69.2%',
#     'ft_m': 7,
#     'ft_a': 0,
#     'reb_o': 2,
#     'pfoul': 6,
#     'profile_picture': None,
#     'name_alt': '揚科維奇',
#     'player_id': 122,
#     'name': None,
#     'jersey': '33',
#     'position': None,
#     'stl': 1,
#     'trey_m': 2,
#     'trey_a': 3,
#     'reb': 6,
#     'tsp': '77.7%',
#     'two_m': 6,
#     'two_a': 2,
#     'ugp': '26.7%',
#     'mins': '29:29',
#     'two': 8,
#     'two_m_two': '6-8',
#     'twop': '75%',
#     'trey': 5,
#     'trey_m_trey': '2-5',
#     'treyp': '40%',
#     'ft': 7,
#     'ft_m_ft': '7-7',
#     'ftp': '100%'},
#    {'points': 13,
#     'positive': -6,
#     'seconds': 1647,
#     'starter': '',
#     'turnover': 1,
#     'ast': 1,
#     'blk': 2,
#     'reb_d': 5,
#     'eff': 19,
#     'efgp': '50%',
#     'ft_m': 4,
#     'ft_a': 0,
#     'reb_o': 3,
#     'pfoul': 0,
#     'profile_picture': None,
#     'name_alt': '布依德',
#     'player_id': 106,
#     'name': None,
#     'jersey': '42',
#     'position': None,
#     'stl': 1,
#     'trey_m': 1,
#     'trey_a': 1,
#     'reb': 8,
#     'tsp': '60.4%',
#     'two_m': 3,
#     'two_a': 4,
#     'ugp': '19.7%',
#     'mins': '27:27',
#     'two': 7,
#     'two_m_two': '3-7',
#     'twop': '42.9%',
#     'trey': 2,
#     'trey_m_trey': '1-2',
#     'treyp': '50%',
#     'ft': 4,
#     'ft_m_ft': '4-4',
#     'ftp': '100%'},
#    {'points': '',
#     'positive': '',
#     'seconds': '',
#     'starter': '',
#     'turnover': '',
#     'ast': '',
#     'blk': '',
#     'reb_d': '',
#     'eff': '',
#     'efgp': '',
#     'ft_m': '',
#     'ft_a': '',
#     'reb_o': '',
#     'pfoul': '',
#     'profile_picture': '',
#     'name_alt': '鄭子洋',
#     'player_id': 113,
#     'name': '',
#     'jersey': '97',
#     'position': '',
#     'stl': '',
#     'trey_m': '',
#     'trey_a': '',
#     'reb': '',
#     'tsp': '',
#     'two_m': '',
#     'two_a': '',
#     'ugp': '',
#     'mins': 'DNP',
#     'two': '',
#     'two_m_two': '',
#     'twop': '',
#     'trey': '',
#     'trey_m_trey': '',
#     'treyp': '',
#     'ft': '',
#     'ft_m_ft': '',
#     'ftp': ''}],
#   'home_total': {'seconds': 14400,
#    'two': 40,
#    'two_m': 21,
#    'trey': 46,
#    'trey_m': 16,
#    'ft': 18,
#    'ft_m': 14,
#    'points': 104,
#    'reb': 39,
#    'reb_o': 11,
#    'reb_d': 28,
#    'ast': 20,
#    'stl': 9,
#    'blk': 2,
#    'turnover': 12,
#    'pfoul': 18,
#    'positive': 35,
#    'mins': '240:00',
#    'twop': 52.5,
#    'treyp': 34.8,
#    'ftp': 77.8},
#   'away': [{'points': 28,
#     'positive': -10,
#     'seconds': 2476,
#     'starter': '〇',
#     'turnover': 4,
#     'ast': 4,
#     'blk': 0,
#     'reb_d': 9,
#     'eff': 30,
#     'efgp': '54.5%',
#     'ft_m': 4,
#     'ft_a': 1,
#     'reb_o': 2,
#     'pfoul': 1,
#     'profile_picture': None,
#     'name_alt': '羅賓森',
#     'player_id': 114,
#     'name': None,
#     'jersey': '0',
#     'position': None,
#     'stl': 3,
#     'trey_m': 2,
#     'trey_a': 7,
#     'reb': 11,
#     'tsp': '57.9%',
#     'two_m': 9,
#     'two_a': 4,
#     'ugp': '33.2%',
#     'mins': '41:16',
#     'two': 13,
#     'two_m_two': '9-13',
#     'twop': '69.2%',
#     'trey': 9,
#     'trey_m_trey': '2-9',
#     'treyp': '22.2%',
#     'ft': 5,
#     'ft_m_ft': '4-5',
#     'ftp': '80%'},
#    {'points': 22,
#     'positive': -11,
#     'seconds': 2207,
#     'starter': '',
#     'turnover': 2,
#     'ast': 3,
#     'blk': 0,
#     'reb_d': 4,
#     'eff': 26,
#     'efgp': '116.7%',
#     'ft_m': 1,
#     'ft_a': 0,
#     'reb_o': 0,
#     'pfoul': 3,
#     'profile_picture': '',
#     'name_alt': '吳家駿',
#     'player_id': 16,
#     'name': None,
#     'jersey': '3',
#     'position': 'G',
#     'stl': 0,
#     'trey_m': 5,
#     'trey_a': 0,
#     'reb': 4,
#     'tsp': '116.5%',
#     'two_m': 3,
#     'two_a': 1,
#     'ugp': '15.3%',
#     'mins': '36:47',
#     'two': 4,
#     'two_m_two': '3-4',
#     'twop': '75%',
#     'trey': 5,
#     'trey_m_trey': '5-5',
#     'treyp': '100%',
#     'ft': 1,
#     'ft_m_ft': '1-1',
#     'ftp': '100%'},
#    {'points': 7,
#     'positive': -7,
#     'seconds': 1216,
#     'starter': '〇',
#     'turnover': 2,
#     'ast': 1,
#     'blk': 1,
#     'reb_d': 8,
#     'eff': 14,
#     'efgp': '62.5%',
#     'ft_m': 2,
#     'ft_a': 0,
#     'reb_o': 1,
#     'pfoul': 1,
#     'profile_picture': '',
#     'name_alt': '施顏宗',
#     'player_id': 15,
#     'name': None,
#     'jersey': '5',
#     'position': 'G',
#     'stl': 0,
#     'trey_m': 1,
#     'trey_a': 0,
#     'reb': 9,
#     'tsp': '71.7%',
#     'two_m': 1,
#     'two_a': 2,
#     'ugp': '16.6%',
#     'mins': '20:16',
#     'two': 3,
#     'two_m_two': '1-3',
#     'twop': '33.3%',
#     'trey': 1,
#     'trey_m_trey': '1-1',
#     'treyp': '100%',
#     'ft': 2,
#     'ft_m_ft': '2-2',
#     'ftp': '100%'},
#    {'points': 8,
#     'positive': 7,
#     'seconds': 1451,
#     'starter': '〇',
#     'turnover': 1,
#     'ast': 2,
#     'blk': 0,
#     'reb_d': 1,
#     'eff': 6,
#     'efgp': '35.7%',
#     'ft_m': 3,
#     'ft_a': 1,
#     'reb_o': 0,
#     'pfoul': 1,
#     'profile_picture': '',
#     'name_alt': '關達祐',
#     'player_id': 17,
#     'name': None,
#     'jersey': '6',
#     'position': 'G',
#     'stl': 2,
#     'trey_m': 1,
#     'trey_a': 1,
#     'reb': 1,
#     'tsp': '45.7%',
#     'two_m': 1,
#     'two_a': 4,
#     'ugp': '19.6%',
#     'mins': '24:11',
#     'two': 5,
#     'two_m_two': '1-5',
#     'twop': '20%',
#     'trey': 2,
#     'trey_m_trey': '1-2',
#     'treyp': '50%',
#     'ft': 4,
#     'ft_m_ft': '3-4',
#     'ftp': '75%'},
#    {'points': '',
#     'positive': '',
#     'seconds': '',
#     'starter': '',
#     'turnover': '',
#     'ast': '',
#     'blk': '',
#     'reb_d': '',
#     'eff': '',
#     'efgp': '',
#     'ft_m': '',
#     'ft_a': '',
#     'reb_o': '',
#     'pfoul': '',
#     'profile_picture': '',
#     'name_alt': '林金榜',
#     'player_id': 126,
#     'name': '',
#     'jersey': '9',
#     'position': '',
#     'stl': '',
#     'trey_m': '',
#     'trey_a': '',
#     'reb': '',
#     'tsp': '',
#     'two_m': '',
#     'two_a': '',
#     'ugp': '',
#     'mins': 'DNP',
#     'two': '',
#     'two_m_two': '',
#     'twop': '',
#     'trey': '',
#     'trey_m_trey': '',
#     'treyp': '',
#     'ft': '',
#     'ft_m_ft': '',
#     'ftp': ''},
#    {'points': 9,
#     'positive': 2,
#     'seconds': 991,
#     'starter': '',
#     'turnover': 1,
#     'ast': 1,
#     'blk': 0,
#     'reb_d': 4,
#     'eff': 9,
#     'efgp': '57.1%',
#     'ft_m': 1,
#     'ft_a': 1,
#     'reb_o': 1,
#     'pfoul': 2,
#     'profile_picture': None,
#     'name_alt': '貝索維奇',
#     'player_id': 120,
#     'name': None,
#     'jersey': '18',
#     'position': None,
#     'stl': 0,
#     'trey_m': 2,
#     'trey_a': 0,
#     'reb': 5,
#     'tsp': '57.1%',
#     'two_m': 1,
#     'two_a': 4,
#     'ugp': '26.8%',
#     'mins': '16:31',
#     'two': 5,
#     'two_m_two': '1-5',
#     'twop': '20%',
#     'trey': 2,
#     'trey_m_trey': '2-2',
#     'treyp': '100%',
#     'ft': 2,
#     'ft_m_ft': '1-2',
#     'ftp': '50%'},
#    {'points': 0,
#     'positive': -7,
#     'seconds': 79,
#     'starter': '',
#     'turnover': 0,
#     'ast': 0,
#     'blk': 0,
#     'reb_d': 0,
#     'eff': 0,
#     'efgp': '0%',
#     'ft_m': 0,
#     'ft_a': 0,
#     'reb_o': 0,
#     'pfoul': 0,
#     'profile_picture': None,
#     'name_alt': '黃泓瀚',
#     'player_id': 75,
#     'name': None,
#     'jersey': '22',
#     'position': None,
#     'stl': 0,
#     'trey_m': 0,
#     'trey_a': 0,
#     'reb': 0,
#     'tsp': '0%',
#     'two_m': 0,
#     'two_a': 0,
#     'ugp': '0%',
#     'mins': '01:19',
#     'two': 0,
#     'two_m_two': '0-0',
#     'twop': '0%',
#     'trey': 0,
#     'trey_m_trey': '0-0',
#     'treyp': '0%',
#     'ft': 0,
#     'ft_m_ft': '0-0',
#     'ftp': '0%'},
#    {'points': 5,
#     'positive': 4,
#     'seconds': 726,
#     'starter': '〇',
#     'turnover': 1,
#     'ast': 1,
#     'blk': 0,
#     'reb_d': 4,
#     'eff': 9,
#     'efgp': '83.3%',
#     'ft_m': 0,
#     'ft_a': 0,
#     'reb_o': 1,
#     'pfoul': 5,
#     'profile_picture': None,
#     'name_alt': '林正',
#     'player_id': 58,
#     'name': None,
#     'jersey': '25',
#     'position': None,
#     'stl': 0,
#     'trey_m': 1,
#     'trey_a': 0,
#     'reb': 5,
#     'tsp': '83.3%',
#     'two_m': 1,
#     'two_a': 1,
#     'ugp': '16.1%',
#     'mins': '12:06',
#     'two': 2,
#     'two_m_two': '1-2',
#     'twop': '50%',
#     'trey': 1,
#     'trey_m_trey': '1-1',
#     'treyp': '100%',
#     'ft': 0,
#     'ft_m_ft': '0-0',
#     'ftp': '0%'},
#    {'points': 4,
#     'positive': -12,
#     'seconds': 1977,
#     'starter': '〇',
#     'turnover': 1,
#     'ast': 5,
#     'blk': 0,
#     'reb_d': 4,
#     'eff': 4,
#     'efgp': '16.7%',
#     'ft_m': 0,
#     'ft_a': 1,
#     'reb_o': 1,
#     'pfoul': 1,
#     'profile_picture': '',
#     'name_alt': '施晉堯',
#     'player_id': 24,
#     'name': None,
#     'jersey': '28',
#     'position': 'G',
#     'stl': 2,
#     'trey_m': 0,
#     'trey_a': 6,
#     'reb': 5,
#     'tsp': '16.1%',
#     'two_m': 2,
#     'two_a': 4,
#     'ugp': '20.3%',
#     'mins': '32:57',
#     'two': 6,
#     'two_m_two': '2-6',
#     'twop': '33.3%',
#     'trey': 6,
#     'trey_m_trey': '0-6',
#     'treyp': '0%',
#     'ft': 1,
#     'ft_m_ft': '0-1',
#     'ftp': '0%'},
#    {'points': 8,
#     'positive': -3,
#     'seconds': 1758,
#     'starter': '',
#     'turnover': 1,
#     'ast': 1,
#     'blk': 1,
#     'reb_d': 4,
#     'eff': 11,
#     'efgp': '70%',
#     'ft_m': 1,
#     'ft_a': 1,
#     'reb_o': 0,
#     'pfoul': 0,
#     'profile_picture': '',
#     'name_alt': '陳冠全',
#     'player_id': 20,
#     'name': None,
#     'jersey': '30',
#     'position': 'G',
#     'stl': 1,
#     'trey_m': 1,
#     'trey_a': 0,
#     'reb': 4,
#     'tsp': '68%',
#     'two_m': 2,
#     'two_a': 2,
#     'ugp': '11.4%',
#     'mins': '29:18',
#     'two': 4,
#     'two_m_two': '2-4',
#     'twop': '50%',
#     'trey': 1,
#     'trey_m_trey': '1-1',
#     'treyp': '100%',
#     'ft': 2,
#     'ft_m_ft': '1-2',
#     'ftp': '50%'},
#    {'points': 0,
#     'positive': -2,
#     'seconds': 99,
#     'starter': '',
#     'turnover': 0,
#     'ast': 0,
#     'blk': 0,
#     'reb_d': 0,
#     'eff': 1,
#     'efgp': '0%',
#     'ft_m': 0,
#     'ft_a': 0,
#     'reb_o': 0,
#     'pfoul': 1,
#     'profile_picture': None,
#     'name_alt': '溫立煌',
#     'player_id': 78,
#     'name': None,
#     'jersey': '45',
#     'position': None,
#     'stl': 1,
#     'trey_m': 0,
#     'trey_a': 0,
#     'reb': 0,
#     'tsp': '0%',
#     'two_m': 0,
#     'two_a': 0,
#     'ugp': '0%',
#     'mins': '01:39',
#     'two': 0,
#     'two_m_two': '0-0',
#     'twop': '0%',
#     'trey': 0,
#     'trey_m_trey': '0-0',
#     'treyp': '0%',
#     'ft': 0,
#     'ft_m_ft': '0-0',
#     'ftp': '0%'},
#    {'points': 6,
#     'positive': 4,
#     'seconds': 1420,
#     'starter': '',
#     'turnover': 3,
#     'ast': 2,
#     'blk': 0,
#     'reb_d': 0,
#     'eff': 0,
#     'efgp': '42.9%',
#     'ft_m': 0,
#     'ft_a': 0,
#     'reb_o': 0,
#     'pfoul': 1,
#     'profile_picture': None,
#     'name_alt': '盧峻翔',
#     'player_id': 76,
#     'name': None,
#     'jersey': '69',
#     'position': None,
#     'stl': 0,
#     'trey_m': 2,
#     'trey_a': 4,
#     'reb': 0,
#     'tsp': '42.9%',
#     'two_m': 0,
#     'two_a': 1,
#     'ugp': '21%',
#     'mins': '23:40',
#     'two': 1,
#     'two_m_two': '0-1',
#     'twop': '0%',
#     'trey': 6,
#     'trey_m_trey': '2-6',
#     'treyp': '33.3%',
#     'ft': 0,
#     'ft_m_ft': '0-0',
#     'ftp': '0%'}],
#   'away_total': {'mins': '240:00',
#    'two': 43,
#    'two_m': 20,
#    'trey': 33,
#    'trey_m': 15,
#    'ft': 17,
#    'ft_m': 12,
#    'points': 97,
#    'reb': 44,
#    'reb_o': 6,
#    'reb_d': 38,
#    'ast': 20,
#    'stl': 9,
#    'blk': 2,
#    'turnover': 16,
#    'pfoul': 16,
#    'positive': -35,
#    'seconds': 14400,
#    'twop': 46.5,
#    'treyp': 45.5,
#    'ftp': 70.6}}}

# %%
url = "https://pleagueofficial.com/game/110"

response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")
# print(soup.prettify())  #輸出排版後的HTML內容

# %%
game_info = soup.find("title").getText().split(" ")
print(game_info) # away | home

if len(game_info) == 5: 
    game_type = game_info[0].split('G')[0]
    game_number = game_info[0].split('G')[1]
    home = game_info[1]
    away = game_info[3].split('│')[0]
else:
    game_type = game_info[0]
    game_number = game_info[1]
    home = game_info[2]
    away = game_info[4].split('│')[0]

print(game_type, game_number, away, home)
# Out:
# ['例行賽G38', '桃園領航猿', 'VS', '新竹街口攻城獅│P.', 'LEAGUE+']
# 例行賽 38 新竹街口攻城獅 桃園領航猿

# %%
['第一站熱身賽', 'G03', '新北國王', 'VS', '臺北富邦勇士│P.', 'LEAGUE+']
['例行賽G84', '桃園領航猿', 'VS', '新竹街口攻城獅│P.', 'LEAGUE+']
['FINALS', 'Game5', '臺北富邦勇士', 'VS', '福爾摩沙台新夢想家│P.', 'LEAGUE+']

# %%
def get_season(play_time) -> str:
    current_year = play_time.year

    if play_time > datetime(current_year, 10, 1):
        season = f"{current_year}-{current_year+1}"
    else:
        season = f"{current_year-1}-{current_year}"
    return season

# %%
time_and_place = soup.find("span", class_="fs14").getText().split(" ")
play_time = datetime.strptime(' '.join(time_and_place[1:3]), '%Y-%m-%d %H:%M')
season = get_season(play_time)
location = time_and_place[-1]
print(play_time, location, season) # Season: Nov. ~ May
# Out:
# 2021-05-16 19:00:00 彰化縣立體育館 2020-2021
